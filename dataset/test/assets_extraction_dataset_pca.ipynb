# %% [markdown]
# # Import tools
# Simulation, Data Manipulation and Math Operations

# %%
# Importing libraries & frameworks 
import random
import torch 
import genesis as gs
import numpy as np
import torch.nn.functional as F
import cv2
import time
import json
from pathlib import Path
from scipy.spatial.transform import Rotation as R
# Out:
# [I 08/15/25 23:50:34.032 620078] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout

# %% [markdown]
# # PyTorch3D
#
# A nice librarie for 3D operations - because of some problems of the python environment (conda) it wasn't possible to import this library properly. So the source functions are pasted here below.
#
# ## Transforms Operation functions
# Reference: https://pytorch3d.readthedocs.io/en/latest/modules/transforms.html

# %%
# from pytorch3d

def _axis_angle_rotation(axis: str, angle: torch.Tensor) -> torch.Tensor:
    """
    Return the rotation matrices for one of the rotations about an axis
    of which Euler angles describe, for each value of the angle given.

    Args:
        axis: Axis label "X" or "Y or "Z".
        angle: any shape tensor of Euler angles in radians

    Returns:
        Rotation matrices as tensor of shape (..., 3, 3).
    """

    cos = torch.cos(angle)
    sin = torch.sin(angle)
    one = torch.ones_like(angle)
    zero = torch.zeros_like(angle)

    if axis == "X":
        R_flat = (one, zero, zero, zero, cos, -sin, zero, sin, cos)
    elif axis == "Y":
        R_flat = (cos, zero, sin, zero, one, zero, -sin, zero, cos)
    elif axis == "Z":
        R_flat = (cos, -sin, zero, sin, cos, zero, zero, zero, one)
    else:
        raise ValueError("letter must be either X, Y or Z.")

    return torch.stack(R_flat, -1).reshape(angle.shape + (3, 3))

def euler_angles_to_matrix(euler_angles: torch.Tensor, convention: str) -> torch.Tensor:
    """
    Convert rotations given as Euler angles in radians to rotation matrices.

    Args:
        euler_angles: Euler angles in radians as tensor of shape (..., 3).
        convention: Convention string of three uppercase letters from
            {"X", "Y", and "Z"}.

    Returns:
        Rotation matrices as tensor of shape (..., 3, 3).
    """
    if euler_angles.dim() == 0 or euler_angles.shape[-1] != 3:
        raise ValueError("Invalid input euler angles.")
    if len(convention) != 3:
        raise ValueError("Convention must have 3 letters.")
    if convention[1] in (convention[0], convention[2]):
        raise ValueError(f"Invalid convention {convention}.")
    for letter in convention:
        if letter not in ("X", "Y", "Z"):
            raise ValueError(f"Invalid letter {letter} in convention string.")
    matrices = [
        _axis_angle_rotation(c, e)
        for c, e in zip(convention, torch.unbind(euler_angles, -1))
    ]
    # return functools.reduce(torch.matmul, matrices)
    return torch.matmul(torch.matmul(matrices[0], matrices[1]), matrices[2])

def standardize_quaternion(quaternions: torch.Tensor) -> torch.Tensor:
    """
    Convert a unit quaternion to a standard form: one in which the real
    part is non negative.

    Args:
        quaternions: Quaternions with real part first,
            as tensor of shape (..., 4).

    Returns:
        Standardized quaternions as tensor of shape (..., 4).
    """
    return torch.where(quaternions[..., 0:1] < 0, -quaternions, quaternions)

def quaternion_raw_multiply(a: torch.Tensor, b: torch.Tensor) -> torch.Tensor:
    """
    Multiply two quaternions.
    Usual torch rules for broadcasting apply.

    Args:
        a: Quaternions as tensor of shape (..., 4), real part first.
        b: Quaternions as tensor of shape (..., 4), real part first.

    Returns:
        The product of a and b, a tensor of quaternions shape (..., 4).
    """
    aw, ax, ay, az = torch.unbind(a, -1)
    bw, bx, by, bz = torch.unbind(b, -1)
    ow = aw * bw - ax * bx - ay * by - az * bz
    ox = aw * bx + ax * bw + ay * bz - az * by
    oy = aw * by - ax * bz + ay * bw + az * bx
    oz = aw * bz + ax * by - ay * bx + az * bw
    return torch.stack((ow, ox, oy, oz), -1)

def quaternion_multiply(a: torch.Tensor, b: torch.Tensor) -> torch.Tensor:
    """
    Multiply two quaternions representing rotations, returning the quaternion
    representing their composition, i.e. the versor with nonnegative real part.
    Usual torch rules for broadcasting apply.

    Args:
        a: Quaternions as tensor of shape (..., 4), real part first.
        b: Quaternions as tensor of shape (..., 4), real part first.

    Returns:
        The product of a and b, a tensor of quaternions of shape (..., 4).
    """
    ab = quaternion_raw_multiply(a, b)
    return standardize_quaternion(ab)

def _sqrt_positive_part(x: torch.Tensor) -> torch.Tensor:
    """
    Returns torch.sqrt(torch.max(0, x))
    but with a zero subgradient where x is 0.
    """
    ret = torch.zeros_like(x)
    positive_mask = x > 0
    if torch.is_grad_enabled():
        ret[positive_mask] = torch.sqrt(x[positive_mask])
    else:
        ret = torch.where(positive_mask, torch.sqrt(x), ret)
    return ret

def matrix_to_quaternion(matrix: torch.Tensor) -> torch.Tensor:
    """
    Convert rotations given as rotation matrices to quaternions.

    Args:
        matrix: Rotation matrices as tensor of shape (..., 3, 3).

    Returns:
        quaternions with real part first, as tensor of shape (..., 4).
    """
    if matrix.size(-1) != 3 or matrix.size(-2) != 3:
        raise ValueError(f"Invalid rotation matrix shape {matrix.shape}.")

    batch_dim = matrix.shape[:-2]
    m00, m01, m02, m10, m11, m12, m20, m21, m22 = torch.unbind(
        matrix.reshape(batch_dim + (9,)), dim=-1
    )

    q_abs = _sqrt_positive_part(
        torch.stack(
            [
                1.0 + m00 + m11 + m22,
                1.0 + m00 - m11 - m22,
                1.0 - m00 + m11 - m22,
                1.0 - m00 - m11 + m22,
            ],
            dim=-1,
        )
    )

    # we produce the desired quaternion multiplied by each of r, i, j, k
    quat_by_rijk = torch.stack(
        [
            # pyre-fixme[58]: `**` is not supported for operand types `Tensor` and
            #  `int`.
            torch.stack([q_abs[..., 0] ** 2, m21 - m12, m02 - m20, m10 - m01], dim=-1),
            # pyre-fixme[58]: `**` is not supported for operand types `Tensor` and
            #  `int`.
            torch.stack([m21 - m12, q_abs[..., 1] ** 2, m10 + m01, m02 + m20], dim=-1),
            # pyre-fixme[58]: `**` is not supported for operand types `Tensor` and
            #  `int`.
            torch.stack([m02 - m20, m10 + m01, q_abs[..., 2] ** 2, m12 + m21], dim=-1),
            # pyre-fixme[58]: `**` is not supported for operand types `Tensor` and
            #  `int`.
            torch.stack([m10 - m01, m20 + m02, m21 + m12, q_abs[..., 3] ** 2], dim=-1),
        ],
        dim=-2,
    )

    # We floor here at 0.1 but the exact level is not important; if q_abs is small,
    # the candidate won't be picked.
    flr = torch.tensor(0.1).to(dtype=q_abs.dtype, device=q_abs.device)
    quat_candidates = quat_by_rijk / (2.0 * q_abs[..., None].max(flr))

    # if not for numerical problems, quat_candidates[i] should be same (up to a sign),
    # forall i; we pick the best-conditioned one (with the largest denominator)
    out = quat_candidates[
        F.one_hot(q_abs.argmax(dim=-1), num_classes=4) > 0.5, :
    ].reshape(batch_dim + (4,))
    return standardize_quaternion(out)

def axis_angle_to_quaternion(axis_angle: torch.Tensor) -> torch.Tensor:
    """
    Convert rotations given as axis/angle to quaternions.

    Args:
        axis_angle: Rotations given as a vector in axis angle form,
            as a tensor of shape (..., 3), where the magnitude is
            the angle turned anticlockwise in radians around the
            vector's direction.

    Returns:
        quaternions with real part first, as tensor of shape (..., 4).
    """
    angles = torch.norm(axis_angle, p=2, dim=-1, keepdim=True)
    sin_half_angles_over_angles = 0.5 * torch.sinc(angles * 0.5 / torch.pi)
    return torch.cat(
        [torch.cos(angles * 0.5), axis_angle * sin_half_angles_over_angles], dim=-1
    )

def vectors_to_quaternion(vectors):
    """
    Convert a batch of 3D vectors to Quaternion angles (wxyz convention).
    
    Parameters:
    vectors : np.ndarray, shape (n, 3)
        Array of n 3D vectors.
    
    Returns:
    quaternions : np.ndarray, shape (n, 4)
        Array of quaternions for each input vector.
    """
    # Ensure input is a PyTorch tensor with shape (n, 3)
    vectors = torch.as_tensor(vectors, dtype=torch.float32)
    if vectors.ndim != 2 or vectors.shape[1] != 3:
        raise ValueError("Input must be a tensor of shape (n, 3)")
    
    # Normalize the vectors
    norms = torch.norm(vectors, dim=1, keepdim=True)  # (n, 1)
    if torch.any(norms == 0):
        raise ValueError("Input contains zero vectors")
    normalized_vectors = vectors / norms
    
    # Reference vector
    reference = torch.tensor([1.0, 0.0, 0.0])
    
    # Compute rotation axes and angles
    dots = torch.clamp(torch.sum(normalized_vectors * reference, dim=1), -1.0, 1.0)
    angles = torch.arccos(dots)
    
    axes = torch.cross(reference.expand_as(normalized_vectors), normalized_vectors)
    axis_norms = torch.norm(axes, dim=1, keepdim=True)
    axes = axes / (axis_norms + 1e-10)  # Avoid division by zero
        
    # Compute rotation vectors (axis-angle)
    rotvecs = angles[:, None] * axes
        
    # Convert to quaternions using provided function
    quaternions = axis_angle_to_quaternion(rotvecs)

    # # Handle cases where vectors are parallel to reference
    # axis_norms = np.linalg.norm(axes, axis=1) # (n, )
    # near_zero = axis_norms < 1e-6
    # axes[near_zero] = np.array([0.0, 0.0, 1.0])  # Arbitrary perpendicular axis
    # axis_norms[near_zero] = 1.0
    
    # # Normalize rotation axes
    # axes = axes / axis_norms[:, np.newaxis] # (n, 3)  / (n, 1)
    
    # # Compute rotation vectors
    # rotvecs = angles[:, np.newaxis] * axes  # (n, 1) * (n, 3)
    
    # # Convert to quaternion angles
    # quaternions = axis_angle_to_quaternion(rotvecs)
    
    # Handle vectors aligned with reference (return zero Euler angles)
    # aligned = np.allclose(normalized_vectors, reference, atol=1e-6)
    # quaternions[aligned] = torch.tensor([1.0, 0., 0., 0.])
    
    return quaternions

def vectors_to_euler(vectors):
    """
    Convert a batch of 3D vectors to Euler angles (xyz convention).
    
    Parameters:
    vectors : np.ndarray, shape (n, 3)
        Array of n 3D vectors.
    
    Returns:
    euler_angles : np.ndarray, shape (n, 3)
        Array of Euler angles in radians for each input vector.
    """
    # Ensure input is a numpy array with shape (n, 3)
    vectors = np.asarray(vectors)
    if vectors.ndim != 2 or vectors.shape[1] != 3:
        raise ValueError("Input must be an array of shape (n, 3)")
    
    # Normalize the vectors
    norms = np.linalg.norm(vectors, axis=1, keepdims=True) # (n, 3) -> (n, 1)
    if np.any(norms == 0):
        raise ValueError("Input contains zero vectors")
    normalized_vectors = vectors / norms
    
    # Reference vector
    reference = np.array([1.0, 0.0, 0.0])
    
    # Compute rotation axes and angles
    axes = np.cross(reference, normalized_vectors)
    dots = np.dot(normalized_vectors, reference)
    angles = np.arccos(dots)
    
    # Handle cases where vectors are parallel to reference
    axis_norms = np.linalg.norm(axes, axis=1) # (n, )
    near_zero = axis_norms < 1e-6
    axes[near_zero] = np.array([0.0, 0.0, 1.0])  # Arbitrary perpendicular axis
    axis_norms[near_zero] = 1.0
    
    # Normalize rotation axes
    axes = axes / axis_norms[:, np.newaxis] # (n, 3)  / (n, 1)
    
    # Compute rotation vectors
    rotvecs = angles[:, np.newaxis] * axes  # (n, 1) * (n, 3)
    
    # Convert to Euler angles
    rotation = R.from_rotvec(rotvecs)
    euler_angles = rotation.as_euler('xyz')
    
    # Handle vectors aligned with reference (return zero Euler angles)
    aligned = np.allclose(normalized_vectors, reference, atol=1e-6)
    euler_angles[aligned] = 0.0
    
    return euler_angles

def quaternion_to_axis_angle(quaternions: torch.Tensor) -> torch.Tensor:
    """
    Convert rotations given as quaternions to axis/angle.

    Args:
        quaternions: quaternions with real part first,
            as tensor of shape (..., 4).

    Returns:
        Rotations given as a vector in axis angle form, as a tensor
            of shape (..., 3), where the magnitude is the angle
            turned anticlockwise in radians around the vector's
            direction.
    """
    norms = torch.norm(quaternions[..., 1:], p=2, dim=-1, keepdim=True)
    half_angles = torch.atan2(norms, quaternions[..., :1])
    sin_half_angles_over_angles = 0.5 * torch.sinc(half_angles / torch.pi)
    # angles/2 are between [-pi/2, pi/2], thus sin_half_angles_over_angles
    # can't be zero
    return quaternions[..., 1:] / sin_half_angles_over_angles

def quaternion_to_matrix(quaternions: torch.Tensor) -> torch.Tensor:
    """
    Convert rotations given as quaternions to rotation matrices.

    Args:
        quaternions: quaternions with real part first,
            as tensor of shape (..., 4).

    Returns:
        Rotation matrices as tensor of shape (..., 3, 3).
    """
    r, i, j, k = torch.unbind(quaternions, -1)
    # pyre-fixme[58]: `/` is not supported for operand types `float` and `Tensor`.
    two_s = 2.0 / (quaternions * quaternions).sum(-1)

    o = torch.stack(
        (
            1 - two_s * (j * j + k * k),
            two_s * (i * j - k * r),
            two_s * (i * k + j * r),
            two_s * (i * j + k * r),
            1 - two_s * (i * i + k * k),
            two_s * (j * k - i * r),
            two_s * (i * k - j * r),
            two_s * (j * k + i * r),
            1 - two_s * (i * i + j * j),
        ),
        -1,
    )
    return o.reshape(quaternions.shape[:-1] + (3, 3))

def matrix_to_euler_angles(matrix: torch.Tensor, convention: str) -> torch.Tensor:
    """
    Convert rotations given as rotation matrices to Euler angles in radians.

    Args:
        matrix: Rotation matrices as tensor of shape (..., 3, 3).
        convention: Convention string of three uppercase letters.

    Returns:
        Euler angles in radians as tensor of shape (..., 3).
    """
    if len(convention) != 3:
        raise ValueError("Convention must have 3 letters.")
    if convention[1] in (convention[0], convention[2]):
        raise ValueError(f"Invalid convention {convention}.")
    for letter in convention:
        if letter not in ("X", "Y", "Z"):
            raise ValueError(f"Invalid letter {letter} in convention string.")
    if matrix.size(-1) != 3 or matrix.size(-2) != 3:
        raise ValueError(f"Invalid rotation matrix shape {matrix.shape}.")
    i0 = _index_from_letter(convention[0])
    i2 = _index_from_letter(convention[2])
    tait_bryan = i0 != i2
    if tait_bryan:
        central_angle = torch.asin(
            matrix[..., i0, i2] * (-1.0 if i0 - i2 in [-1, 2] else 1.0)
        )
    else:
        central_angle = torch.acos(matrix[..., i0, i0])

    o = (
        _angle_from_tan(
            convention[0], convention[1], matrix[..., i2], False, tait_bryan
        ),
        central_angle,
        _angle_from_tan(
            convention[2], convention[1], matrix[..., i0, :], True, tait_bryan
        ),
    )
    return torch.stack(o, -1)

def _index_from_letter(letter: str) -> int:
    if letter == "X":
        return 0
    if letter == "Y":
        return 1
    if letter == "Z":
        return 2
    raise ValueError("letter must be either X, Y or Z.")

def _angle_from_tan(
    axis: str, other_axis: str, data, horizontal: bool, tait_bryan: bool
) -> torch.Tensor:
    """
    Extract the first or third Euler angle from the two members of
    the matrix which are positive constant times its sine and cosine.

    Args:
        axis: Axis label "X" or "Y or "Z" for the angle we are finding.
        other_axis: Axis label "X" or "Y or "Z" for the middle axis in the
            convention.
        data: Rotation matrices as tensor of shape (..., 3, 3).
        horizontal: Whether we are looking for the angle for the third axis,
            which means the relevant entries are in the same row of the
            rotation matrix. If not, they are in the same column.
        tait_bryan: Whether the first and third axes in the convention differ.

    Returns:
        Euler Angles in radians for each matrix in data as a tensor
        of shape (...).
    """

    i1, i2 = {"X": (2, 1), "Y": (0, 2), "Z": (1, 0)}[axis]
    if horizontal:
        i2, i1 = i1, i2
    even = (axis + other_axis) in ["XY", "YZ", "ZX"]
    if horizontal == even:
        return torch.atan2(data[..., i1], data[..., i2])
    if tait_bryan:
        return torch.atan2(-data[..., i2], data[..., i1])
    return torch.atan2(data[..., i2], -data[..., i1])

def matrix_to_axis_angle(matrix: torch.Tensor, fast: bool = False) -> torch.Tensor:
    """
    Convert rotations given as rotation matrices to axis/angle.

    Args:
        matrix: Rotation matrices as tensor of shape (..., 3, 3).
        fast: Whether to use the new faster implementation (based on the
            Rodrigues formula) instead of the original implementation (which
            first converted to a quaternion and then back to a rotation matrix).

    Returns:
        Rotations given as a vector in axis angle form, as a tensor
            of shape (..., 3), where the magnitude is the angle
            turned anticlockwise in radians around the vector's
            direction.

    """
    if not fast:
        return quaternion_to_axis_angle(matrix_to_quaternion(matrix))

    if matrix.size(-1) != 3 or matrix.size(-2) != 3:
        raise ValueError(f"Invalid rotation matrix shape {matrix.shape}.")

    omegas = torch.stack(
        [
            matrix[..., 2, 1] - matrix[..., 1, 2],
            matrix[..., 0, 2] - matrix[..., 2, 0],
            matrix[..., 1, 0] - matrix[..., 0, 1],
        ],
        dim=-1,
    )
    norms = torch.norm(omegas, p=2, dim=-1, keepdim=True)
    traces = torch.diagonal(matrix, dim1=-2, dim2=-1).sum(-1).unsqueeze(-1)
    angles = torch.atan2(norms, traces - 1)

    zeros = torch.zeros(3, dtype=matrix.dtype, device=matrix.device)
    omegas = torch.where(torch.isclose(angles, torch.zeros_like(angles)), zeros, omegas)

    near_pi = angles.isclose(angles.new_full((1,), torch.pi)).squeeze(-1)

    axis_angles = torch.empty_like(omegas)
    axis_angles[~near_pi] = (
        0.5 * omegas[~near_pi] / torch.sinc(angles[~near_pi] / torch.pi)
    )

    # this derives from: nnT = (R + 1) / 2
    n = 0.5 * (
        matrix[near_pi][..., 0, :]
        + torch.eye(1, 3, dtype=matrix.dtype, device=matrix.device)
    )
    axis_angles[near_pi] = angles[near_pi] * n / torch.norm(n)

    return axis_angles

# %% [markdown]
# # Initializing Genesis
#
# Below is defined some setup the scene and camera as well as the definition of the Rigid Body Entities used in the Grasp (Bottle and the Spot Gripper).
#
# Note: in the last line is defined the number of Parallel Environment.

# %%
# Genesis initialization 
gs.init(
    backend=gs.cuda,
    seed=None,
    precision='32',
    debug=False,
    eps=1e-12,
    logging_level=None,
    theme='dark',
    logger_verbose_time=False
)

# Creating the scene
scene = gs.Scene(
    viewer_options=gs.options.ViewerOptions(
        camera_pos=(0, 0, 1.0),
        camera_lookat=(0, 0, 0.15),
        camera_fov=30,
        max_FPS=600
    ),
    vis_options=gs.options.VisOptions(show_world_frame=False),
    sim_options=gs.options.SimOptions(dt=0.001),
    show_viewer=True, 
    show_FPS=False
)

# Plane (ground) 
plane = scene.add_entity(gs.morphs.Plane())

initial_gripper_pos = [-1, 0.0, 0.10]
initial_gripper_quat = [0.707, 0.707, 0, 0]
spot_gripper = scene.add_entity(
    gs.morphs.URDF(
        file='/home/nexus/Desktop/spot_gen/spot_arm_description/spot_arm/urdf/open_gripper.urdf',
        quat = initial_gripper_quat,
        pos=initial_gripper_pos,
        scale=1.0,
        merge_fixed_links=True,
        fixed = True
    ),
)

drill_pos = [-0.05, 0.0, 0.075] 
drill = scene.add_entity(
    gs.morphs.Mesh(
        file="../tools/drill.glb", 
        pos=drill_pos,            
        euler=(90, 0, 0),
        collision=True,
        visualization=True,
        convexify = True,
        parse_glb_with_trimesh = True,
        merge_submeshes_for_collision = True,
        fixed=True,          
        scale=0.00015                      
    )
)

# Camera Setup
cam = scene.add_camera(
    pos    =(3, -1.5, 0.2),
    lookat = (0.0, 0.0, 0.09),
    res    = (640, 480),
    fov    = 30,
    GUI    = False,
    up = (0, 0, 1),

)
# Building the Scene
scene.build(n_envs=5)
# Out:
# [Genesis] [23:50:36] [INFO] ╭───────────────────────────────────────────────╮
# [Genesis] [23:50:36] [INFO] │┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈ Genesis ┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈│
# [Genesis] [23:50:36] [INFO] ╰───────────────────────────────────────────────╯
# [Genesis] [23:50:36] [INFO] Running on [NVIDIA RTX A2000 12GB] with backend gs.cuda. Device memory: 11.63 GB.
# [Genesis] [23:50:36] [INFO] 🚀 Genesis initialized. 🔖 version: 0.2.1, 🌱 seed: None, 📏 precision: '32', 🐛 debug: False, 🎨 theme: 'dark'.
# [Genesis] [23:50:36] [INFO] Scene <63dd9c2> created.
# [Genesis] [23:50:36] [INFO] Adding <gs.RigidEntity>. idx: 0, uid: <60155cb>, morph: <gs.morphs.Plane>, material: <gs.materials.Rigid>.
# [Genesis] [23:50:37] [INFO] Adding <gs.RigidEntity>. idx: 1, uid: <49bf390>, morph: <gs.morphs.URDF(file='/home/nexus/Desktop/spot_gen/spot_arm_description/spot_arm/urdf/open_gripper.urdf')>, material: <gs.materials.Rigid>.
# [Genesis] [23:50:37] [INFO] Adding <gs.RigidEntity>. idx: 2, uid: <aa0d5e5>, morph: <gs.morphs.Mesh(file='/home/nexus/Desktop/spot_gen/Exp_RigidEntity/tools/drill.glb')>, material: <gs.materials.Rigid>.
# [Genesis] [23:50:37] [INFO] Building scene <63dd9c2>...
# [Genesis] [23:50:41] [INFO] Compiling simulation kernels...
# [Genesis] [23:51:05] [INFO] Building visualizer...
# [Genesis] [23:51:06] [INFO] Viewer created. Resolution: 720×540, max_FPS: 600.

# %% [markdown]
# ## Control Parameters Definition
# Here is defined the range of kv, kp, the Degress of Freedom as well it's force.

# %%
# Define DOFs
hand_dof = np.arange(2)
finger_dof = np.array([1]) 
initial_gripper_dof_state = spot_gripper.get_dofs_position()  # Shape: (n_envs, num_dofs)
initial_finger_dof_pos = initial_gripper_dof_state[:, finger_dof].squeeze()  # Shape: (n_envs,)
print("Initial shapes: initial_gripper_dof_state:", initial_gripper_dof_state.shape, "initial_finger_dof_pos:", initial_finger_dof_pos.shape)
# Set PD control parameters
spot_gripper.set_dofs_kp(
    np.array([100]*2)
    )
spot_gripper.set_dofs_kv(
    np.array([1]*2)
    )
spot_gripper.set_dofs_force_range(
    np.array([-100]*2),
    np.array([100]*2)
    )
# TODO: verify the asset link name and replace the plastic_bottle_base_link in check_asset_contacts -> idx link
# Out:
# Initial shapes: initial_gripper_dof_state: torch.Size([5, 2]) initial_finger_dof_pos: torch.Size([5])

# %% [markdown]
# ## Grasping helper functions
#
# During the study some functions were created to make the automated grasp possible.

# %%
# Grasping helper functions
def pixel_to_world(x, y, depth, cam_pos, cam_lookat, fov, img_width, img_height, world_up):
    """
    Convert a batch of pixel coordinates and depths to world coordinates.

    Args:
        x: array of pixel x-coordinates (horizontal) [N]
        y: array of pixel y-coordinates (vertical) [N]
        depth: array of depth values at those pixels [N]
        cam_pos: camera position (x, y, z)
        cam_lookat: point camera is looking at (x, y, z)
        fov: field of view in degrees
        img_width: width of the image in pixels
        img_height: height of the image in pixels
        world_up: world up vector (x, y, z)

    Returns:
        world_coords: array of (x, y, z) in world coordinates [N, 3]
    """
    # Convert inputs to numpy arrays
    cam_pos = np.array(cam_pos)
    cam_lookat = np.array(cam_lookat)
    world_up = np.array(world_up)
    x = np.array(x)
    y = np.array(y)
    depth = np.array(depth)

    # Calculate camera direction vector
    cam_dir = cam_lookat - cam_pos
    cam_dir = cam_dir / np.linalg.norm(cam_dir)

    # Calculate camera up vector
    cam_right = np.cross(cam_dir, world_up)
    cam_right = cam_right / np.linalg.norm(cam_right)
    cam_up = np.cross(cam_right, cam_dir)

    # Convert FOV to radians
    fov_rad = np.deg2rad(fov)

    # Calculate direction vector in camera space
    aspect_ratio = img_width / img_height
    tan_half_fov = np.tan(fov_rad / 2.0)

    # Calculate pixel coordinates in normalized device coordinates (-1 to 1)
    ndc_x = (2.0 * x / (img_width - 1)) - 1.0
    ndc_y = 1.0 - (2.0 * y / (img_height - 1))  # Flip y-axis

    # Calculate camera space coordinates
    cam_space_x = ndc_x * tan_half_fov * aspect_ratio
    cam_space_y = ndc_y * tan_half_fov
    cam_space_z = -1.0 * np.ones_like(cam_space_x)  # Negative z is forward

    # Create direction vectors in camera space
    cam_space_dir = np.stack([cam_space_x, cam_space_y, cam_space_z], axis=-1)
    cam_space_dir = cam_space_dir / np.linalg.norm(cam_space_dir, axis=-1, keepdims=True)

    # Convert to world space direction
    world_dir = (cam_right * cam_space_dir[..., 0:1] +
                 cam_up * cam_space_dir[..., 1:2] +
                 -cam_dir * cam_space_dir[..., 2:3])
    world_dir = world_dir / np.linalg.norm(world_dir, axis=-1, keepdims=True)
    # Calculate world positions
    world_pos = cam_pos + world_dir * depth[..., None]

    # print(f"World DIrection, Position: {world_dir}\n {world_pos}")
    return world_pos

def check_asset_contact(envs_idx=None):
    """
    Check if both specified gripper links are in contact with the asset.

    Args:
        envs_idx (np.ndarray, optional): Environment indices to process. If None, process all.

    Returns:
        torch.Tensor: Boolean tensor of shape (len(envs_idx),) indicating if BOTH
                      'arm_link_wr1' AND 'arm_link_fngr' have contact with the asset.
    """
    # Determine environments to process
    if envs_idx is None:
        envs_idx = np.arange(scene.n_envs)
    num_envs_active = len(envs_idx)
    envs_idx_tensor = torch.tensor(envs_idx, device='cuda', dtype=torch.long)

    # Get contact data between the gripper and the asset
    contacts = spot_gripper.get_contacts(with_entity=drill)
    
    # Handle empty or invalid contact data
    if not contacts or 'position' not in contacts:
        return torch.zeros(num_envs_active, dtype=torch.bool, device='cuda')

    # Get link names and indices for the specific gripper links
    link_names = [l.name for l in scene.rigid_solver.links]
    asset_link_idx = link_names.index("drill_glb_baselink") if "drill_glb_baselink" in link_names else -1
    if asset_link_idx == -1:
        raise ValueError("No asset found on links")

    try:
        wr1_link_idx = link_names.index("arm_link_wr1")
        fngr_link_idx = link_names.index("arm_link_fngr")
    except ValueError:
        # If one of the links isn't found, it's impossible for both to be in contact
        return torch.zeros(num_envs_active, dtype=torch.bool, device='cuda')

    # Convert contact data to PyTorch tensors for GPU processing
    link_a = torch.tensor(contacts['link_a'], device='cuda', dtype=torch.long)
    link_b = torch.tensor(contacts['link_b'], device='cuda', dtype=torch.long)
    valid_mask = torch.tensor(contacts['valid_mask'], device='cuda', dtype=torch.bool)

    # Check for valid contacts involving the first finger (arm_link_wr1)
    is_a_wr1 = (link_a == wr1_link_idx)
    is_b_wr1 = (link_b == wr1_link_idx)
    valid_wr1_contacts = valid_mask & (is_a_wr1 | is_b_wr1)
    
    # Check for valid contacts involving the second finger (arm_link_fngr)
    is_a_fngr = (link_a == fngr_link_idx)
    is_b_fngr = (link_b == fngr_link_idx)
    valid_fngr_contacts = valid_mask & (is_a_fngr | is_b_fngr)

    # Filter for the specified environments
    valid_wr1_active = valid_wr1_contacts[envs_idx_tensor]
    valid_fngr_active = valid_fngr_contacts[envs_idx_tensor]

    # For each environment, determine if it has at least one contact for each link
    has_wr1_contact = valid_wr1_active.any(dim=1)   # Shape: (num_envs_active,)
    # if has_wr1_contact.any():
    #     print(f"Gripper link 'arm_link_wr1' has contact in {has_wr1_contact.sum().item()} environments.")
    has_fngr_contact = valid_fngr_active.any(dim=1) # Shape: (num_envs_active,)
    # if has_fngr_contact.any():
    #     print(f"Gripper link 'arm_link_fngr' has contact in {has_fngr_contact.sum().item()} environments.")
    # The final result is True only if BOTH conditions are met for an environment
    had_contact_on_both = has_wr1_contact & has_fngr_contact # Logical AND
    # if had_contact_on_both.any():
    #     print(f"Both gripper links have contact in {had_contact_on_both.sum().item()} environments.")
    return had_contact_on_both

def perform_grasp(num_steps=10, pause_steps=10, max_gripper_pos=torch.pi/2, envs_idx=None):
    """
    Perform grasp by closing the gripper in specified environments.

    Args:
        num_steps (int): Number of steps to close the gripper.
        pause_steps (int): Simulation steps per grasp step for stabilization.
        max_gripper_pos (float): Maximum gripper joint position (radians).
        envs_idx (np.ndarray, optional): Environment indices to process. If None, process all.

    Returns:
        torch.Tensor: A tensor of shape (len(envs_idx),) containing the gripper angle
                      at the moment of first contact for each environment.
                      A value of -1 indicates no contact was made.    
    """
    # start = time.time()
    # Ensure envs_idx is a NumPy array
    if envs_idx is None:
        envs_idx = np.arange(scene.n_envs)
    envs_idx = np.asarray(envs_idx)
    num_envs_active = len(envs_idx)

    # Stores the angle at which contact occurred. Initialize with NaN (no contact).
    contact_angles = torch.full((num_envs_active,), -1.0, device='cuda')
    # A boolean mask to track which environments have already made contact.
    has_contacted = torch.zeros(num_envs_active, dtype=torch.bool, device='cuda')

    # Get current joint positions
    current_qpos = spot_gripper.get_dofs_position()  # Shape: (n_envs, num_dofs)
    start_gripper_pos = current_qpos[:, finger_dof]  # Shape: (n_envs,)
    
    # Compute step size for active environments
    gripper_step_size = (max_gripper_pos - start_gripper_pos[envs_idx]) / num_steps  # Shape: (num_envs_active,)
    
    # Validate shapes
    if gripper_step_size.shape != (num_envs_active,):
        gripper_step_size = gripper_step_size.squeeze()  # Ensure (num_envs_active,)
    if start_gripper_pos[envs_idx].shape != (num_envs_active,):
        start_gripper_pos = start_gripper_pos[envs_idx].squeeze()  # Ensure (num_envs_active,)

    for i in range(num_steps + 1):
        # Compute gripper positions for active environments
        current_gripper_pos = start_gripper_pos[envs_idx] + i * gripper_step_size  # Shape: (num_envs_active,)
        current_gripper_pos = current_gripper_pos.squeeze()  # Ensure (num_envs_active,)
        
        # Update target positions for active environments
        target_qpos = current_qpos.clone()  # Shape: (n_envs, num_dofs)
        target_qpos[envs_idx, finger_dof] = current_gripper_pos  # Shape: (num_envs_active,)
        
        # Debug shapes
        # print(f"Step {i}: current_gripper_pos shape: {current_gripper_pos.shape}, target slice shape: {target_qpos[envs_idx, finger_dof].shape}")
        
        spot_gripper.control_dofs_position(target_qpos)
        
        # Run simulation steps
        for _ in range(pause_steps):
            scene.step()
            
        envs_to_check_idx = envs_idx[~has_contacted.cpu()]
        if len(envs_to_check_idx) == 0:
            break  # Exit early if all environments have registered contact

        # Perform the contact check on the subset of environments
        new_contacts = check_asset_contact(envs_idx=envs_to_check_idx)

        # If any new contacts were detected
        if new_contacts.any():
            # Get the gripper's *actual* current joint positions
            live_gripper_pos = spot_gripper.get_dofs_position()[envs_to_check_idx, finger_dof]

            # Find which of the checked environments just made contact
            just_contacted_mask = new_contacts

            # Record the angle for those specific environments
            # Map the results from the subset back to the main `contact_angles` tensor
            original_indices_mask = torch.zeros_like(has_contacted)
            original_indices_mask[~has_contacted] = just_contacted_mask
            contact_angles[original_indices_mask] = live_gripper_pos[just_contacted_mask]

            # Update the master list of contacted environments
            has_contacted[original_indices_mask] = True

    for _ in range(200):
        scene.step()
    # end  = time.time()
    # print(f"Grasping took {end - start:.4f}s.")
    return contact_angles

def check_floor_contact(envs_idx=None):
    """
    Check gripper-floor contacts in specified environments.

    Args:
        envs_idx (np.ndarray, optional): Environment indices to process. If None, process all.

    Returns:
        torch.Tensor: Boolean tensor of shape (len(envs_idx),) indicating contact.
    """
    if envs_idx is None:
        envs_idx = np.arange(scene.n_envs)
    num_envs_active = len(envs_idx)
    envs_idx_tensor = torch.tensor(envs_idx, device='cuda', dtype=torch.long)

    contacts = spot_gripper.get_contacts(with_entity=plane)
    
    if not contacts or 'position' not in contacts:
        return torch.zeros(num_envs_active, dtype=torch.bool, device='cuda')
    
    had_contact = torch.zeros(num_envs_active, dtype=torch.bool, device='cuda')
    
    link_names = [l.name for l in scene.rigid_solver.links]
    floor_link_idx = link_names.index("plane_baselink") if "plane_baselink" in link_names else -1

    if floor_link_idx == -1:
        raise ValueError("No floor found on links")

    # Convert valid_mask to PyTorch tensor
    valid_mask = torch.tensor(contacts['valid_mask'], device='cuda', dtype=torch.bool)

    # Use tensor operations for efficiency
    valid_contacts = valid_mask[envs_idx_tensor]  # (num_envs_active, num_contacts)
    had_contact = valid_contacts.any(dim=1)  # (num_envs_active,)

    return had_contact

def quaternion_from_euler(angles, seq='XYZ'):
    rot_matrix = euler_angles_to_matrix(angles, convention=seq.upper())
    quat_wxyz = matrix_to_quaternion(rot_matrix)  # Shape: (4,), [w, x, y, z]
    return quat_wxyz

def rotate_90(quaternion, envs_idx):
    converted_matrix_orientation = quaternion_to_matrix(quaternion)
    converted_euler_orientation = matrix_to_euler_angles(converted_matrix_orientation, convention="ZYX")
    converted_euler_orientation[:,2] = np.pi/2
    converted_matrix_from_euler = euler_angles_to_matrix(converted_euler_orientation, convention="ZYX")
    converted_quat_from_axis_angle = matrix_to_quaternion(converted_matrix_from_euler)
    spot_gripper.set_quat(converted_quat_from_axis_angle, envs_idx=envs_idx)

def is_in_xy_plane(quaternion, envs_idx):
    """
    Checks if the gripper is oriented in the XY plane and rotates it if necessary.

    This function determines if the gripper's local Z-axis is perpendicular to the world Z-axis.
    If so, it uses the `rotate_90` function to apply a 90-degree roll.

    Args:
        quaternion (torch.Tensor): The current orientation of the grippers for the specified environments,
                                   as a tensor of shape (num_envs, 4).
        envs_idx (np.ndarray): The indices of the environments to check.
    """
    # start = time.time()
    if quaternion.dim() == 1:
        quaternion = quaternion.unsqueeze(0)

    # Convert quaternion to rotation matrix
    rot_matrix = quaternion_to_matrix(quaternion)

    # Get the gripper's local Z-axis (third column of the rotation matrix)
    local_z_axis = rot_matrix[..., :, 2]

    # Define the world's Z-axis
    world_z_axis = torch.tensor([0.0, 0.0, 1.0], dtype=quaternion.dtype, device=quaternion.device)

    # Absolute dot product between the local and world Z-axes.
    # If the axes are perpendicular, the dot product will be close to 0.
    dot_product = torch.abs(torch.sum(local_z_axis * world_z_axis, dim=-1))

    # Identify grippers in the XY plane (dot product is near zero)
    # This creates a boolean mask for the environments that need rotation.
    envs_to_rotate_mask = torch.isclose(dot_product, torch.tensor(0.0), atol=1e-3)
    
    # Convert the boolean mask to an array of indices
    indices_to_rotate = envs_idx[envs_to_rotate_mask.cpu().numpy()]

    # If any grippers need to be rotated, call rotate_90
    if indices_to_rotate.size > 0:
        # print(f"\033[1;92mGripper is in XY plane for envs {indices_to_rotate}. Rotating by pi/2...\033[0m")
        
        # Select the quaternions of the grippers that need rotation
        quats_to_rotate = quaternion[envs_to_rotate_mask]
        
        # Call the rotation function for the specific environments
        rotate_90(quats_to_rotate, envs_idx=indices_to_rotate)
        return True
    # else:
        # print("\033[1;92mGripper is vertical, no rotation needed.\033[0m")
        return False
    end = time.time()
    # print(f"Rotation check took {end - start:.4f}s.")
    
def approach(vector_normal, grasp_point, envs_idx, k_dist = 0.35):
    # start = time.time()
    spot_gripper.set_pos((k_dist) * vector_normal+grasp_point, envs_idx=envs_idx)  
    # end = time.time()
    # print(f"Approach took {end - start:.4f}s.")

def apply_roll_orientation(base_quaternion, roll_angle, envs_idx):
    """
    Applies a roll rotation to the gripper's current orientation.

    Args:
        base_quaternion (torch.Tensor): The initial quaternion orientation.
        roll_angle (float): The roll angle in radians to apply.
        envs_idx (np.ndarray): Environment indices to process.
    """
    # Convert quaternion to rotation matrix, then to ZYX Euler angles
    rot_matrix = quaternion_to_matrix(base_quaternion)
    euler_angles = matrix_to_euler_angles(rot_matrix, convention="ZYX")

    # Add the roll angle to the existing Z-axis rotation
    euler_angles[:, 2] += roll_angle

    # Convert back to matrix, then to quaternion
    new_rot_matrix = euler_angles_to_matrix(euler_angles, convention="ZYX")
    new_quaternion = matrix_to_quaternion(new_rot_matrix)

    # Set the new orientation for the specified grippers
    spot_gripper.set_quat(new_quaternion, envs_idx=envs_idx)

# %% [markdown]
# # Principal Components Analysis helper functions
# Helper functions to obtain the Asset's Principal Axis and adjust gripper's roll rotation for a better grasp in non simmentrical geometrys

# %%
def get_local_point_cloud(center_x, center_y, patch_size, depth, cam_pos, cam_lookat, fov, img_width, img_height, up):
    """
    Extracts a batch of local point clouds from a depth map using NumPy.
    """
    half = patch_size // 2
    num_envs = len(center_x)
    
    offsets = np.arange(-half, half + 1)
    grid_x, grid_y = np.meshgrid(offsets, offsets)

    expanded_x = center_x[:, np.newaxis, np.newaxis] + grid_x
    expanded_y = center_y[:, np.newaxis, np.newaxis] + grid_y
    
    expanded_x = np.clip(expanded_x, 0, img_width - 1)
    expanded_y = np.clip(expanded_y, 0, img_height - 1)

    flat_x = expanded_x.ravel()
    flat_y = expanded_y.ravel()

    patch_depths = depth[flat_y, flat_x]

    world_coords = pixel_to_world(
        flat_x, flat_y, patch_depths,
        cam_pos, cam_lookat, fov, img_width, img_height, up
    )
    
    point_clouds = world_coords.reshape(num_envs, patch_size * patch_size, 3)
    
    return point_clouds

def get_principal_axes_batch(point_clouds):
    """
    Performs PCA on a batch of point clouds to find the axis of minimum curvature.
    """
    mean = torch.mean(point_clouds, dim=1, keepdim=True)
    centered_clouds = point_clouds - mean
    
    B, N, D = centered_clouds.shape
    covariance_matrices = torch.bmm(centered_clouds.transpose(1, 2), centered_clouds) / (N - 1)
    
    _, eigenvectors = torch.linalg.eigh(covariance_matrices)
    
    min_curvature_axes = eigenvectors[:, :, 1]
    
    return min_curvature_axes

def apply_pca_roll_adjustment(envs_idx, target_up_vectors):
    """
    Adjusts the gripper's roll to align its fingers with the target_up_vectors.
    """
    # 1. Get the gripper's current orientation and axes
    current_quats = spot_gripper.get_quat(envs_idx=envs_idx)
    rot_matrices = quaternion_to_matrix(current_quats)
    current_up_vectors = rot_matrices[:, :, 1]  # Gripper's Y-axis
    approach_vectors = -rot_matrices[:, :, 2] # Gripper's -Z axis

    # 2. Calculate the required roll angle between current and target 'up' vectors
    dot_product = torch.sum(current_up_vectors * target_up_vectors, dim=-1)
    cross_product = torch.cross(current_up_vectors, target_up_vectors, dim=-1)
    sign = torch.sign(torch.sum(cross_product * approach_vectors, dim=-1))
    angle = torch.acos(torch.clamp(dot_product, -1.0, 1.0))
    roll_angles = angle * sign

    # 3. Create a quaternion representing this relative roll adjustment
    half_angles = roll_angles / 2.0
    w = torch.cos(half_angles)
    sin_half_angles = torch.sin(half_angles)
    xyz = approach_vectors * sin_half_angles.unsqueeze(-1)
    roll_correction_quat = torch.cat([w.unsqueeze(-1), xyz], dim=-1)

    # 4. Apply the correction to the current orientation
    final_quats = quaternion_multiply(current_quats, roll_correction_quat)
    
    # 5. Set the new orientation on the grippers
    spot_gripper.set_quat(final_quats, envs_idx=envs_idx)
    
    for _ in range(5):
        scene.step()

# %% [markdown]
# ## Dataset Parameters
#
# Below some parameters for the dataset creation are defined.

# %%
# Output directory
pre_dataset_dir = Path("./drill/drill_dataset")
pre_dataset_dir.mkdir(parents=True, exist_ok=True)

# Number of samples
num_samples = 1000

# Up direction reference
up = [0, 0, 1]

# Camera parameters
img_width, img_height, fov = 640, 480, 30

# %% [markdown]
# ## Extraction Data Loop
#
# In this loop all the randomization, robot action, data save happens.

# %%
from tqdm import tqdm
for i in tqdm(range(num_samples), desc="Grasped samples"):
    #  View setup 
    view_id = f"view_{i}" 
    view_dir = pre_dataset_dir / view_id

    # print("Load data")
    # Load saved data from .npy files
    rgb = np.load(view_dir / "rgb.npy")
    depth = np.load(view_dir / "depth.npy")
    normal_map = np.load(view_dir / "normal.npy")
    seg = np.load(view_dir / "segmentation.npy")
    bottle_pixels = np.where(seg == 2)
    bottle_pixels = np.transpose(np.array(bottle_pixels))  # Shape: (num_pixels, 2)
    # Load saved data from JSON file
    with open(view_dir / "metadata.json", "r") as f:
        metadata = json.load(f)
        cam_pos = metadata["camera_pos"]
        cam_lookat = metadata["camera_lookat"]
        up = metadata["up"]
        
    # Check number of asset pixels
    num_pixels = len(bottle_pixels)
    if num_pixels == 0:
        # print(f"Warning: No asset pixels in {view_id}. Skipping grasp simulation.")
        continue

    # Limit number of active environments to number of asset pixels
    active_envs = min(scene.n_envs, num_pixels)  # Use fewer grippers if num_pixels < n_envs
    active_env_indices = np.arange(active_envs)  # Indices: [0, 1, ..., active_envs-1]

    # Select random pixels (one per active environment)
    if num_pixels <= active_envs:
        # Use all pixels directly
        selected_indices = np.arange(num_pixels)
    else:
        # Randomly sample active_envs pixels
        selected_indices = np.random.choice(num_pixels, size=active_envs, replace=False)
    
    selected_pixels = bottle_pixels[selected_indices]  # Shape: (active_envs, 2)
    # print(f"Selected pixels: {selected_pixels.shape}")
    random_y, random_x = selected_pixels.T  # Shape: (active_envs,)
    # print(f"Pixel (x,y): ({random_x}, {random_y})")
    # Get depth and normal at selected pixels
    specific_point_depth = depth[random_y, random_x]  # Shape: (active_envs,)
    specific_point_normal = normal_map[random_y, random_x]  # Shape: (active_envs, 3)
    vector_normal = 2 * (specific_point_normal - 127.5) / 255  # Normalize to [-1, 1]

    # Compute grasp points and orientations
    # print("Pixel to World")
    grasp_point = pixel_to_world(
        random_x, random_y, specific_point_depth, cam_pos, cam_lookat, fov, img_width, img_height, up
    )
    quaternions = vectors_to_quaternion(-torch.tensor(vector_normal))
    position = grasp_point + 0.5 * vector_normal.copy()
    # print(f"Grasp point: {grasp_point}\n")
    # print(f"Position: {position}\n")
    # print(f"quaternions: {quaternions}")
    # Set gripper poses only for active environments
    # print("Set pos/quat")
    spot_gripper.set_pos(position, envs_idx=active_env_indices)
    spot_gripper.set_quat(quaternions, envs_idx=active_env_indices)

    # Rotate gripper for better grasping
    # is_in_xy_plane(quaternions, envs_idx=active_env_indices)
    # TODO: Debug below: Is the principal axis wrong or the finger roll wrong?
    # ADJUST FINGER ORIENTATION (ROLL) using PCA
    # This section replaces the `for roll in roll_angles:` loop and `is_in_xy_plane`.
    local_clouds_np = get_local_point_cloud(
        random_x, random_y, patch_size=9, depth=depth,
        cam_pos=cam_pos, cam_lookat=cam_lookat, fov=fov,
        img_width=img_width, img_height=img_height, up=up
    )
    local_clouds_torch = torch.tensor(local_clouds_np, dtype=torch.float32, device='cuda')
    target_up_vectors = get_principal_axes_batch(local_clouds_torch)

    # Apply the calculated roll adjustment to the currently posed grippers
    apply_pca_roll_adjustment(active_env_indices, target_up_vectors)

    # Move gripper closer to the bottle
    approach(vector_normal, grasp_point, envs_idx=active_env_indices, k_dist=0.18)
    for _ in range(2):
        scene.step()

    # Perform grasp
    # print("finger_dof type:", type(finger_dof), "value:", finger_dof)
    contact_angle = perform_grasp(envs_idx=active_env_indices)  # Modified to support envs_idx
    for _ in range(400):
        scene.step()
    # print("Checking for contacts. . . ")
    # Check contacts only for active environments
    bottle_contacts = (contact_angle != -1)       # check_asset_contact(envs_idx=active_env_indices)
    # print(f"\nGripper contacts with the bottle:\n{bottle_contacts}")
    floor_contacts = check_floor_contact(envs_idx=active_env_indices)
    # print(f"\nGripper contacts with the floor:\n{floor_contacts}")
    final_contacts = torch.logical_and(bottle_contacts, ~floor_contacts)
    # print(f"\nFinal contacts:\n{final_contacts}")
    final_contacts = final_contacts.cpu().numpy().tolist()  # Length: active_envs

    # Store metadata
    data_metadata = {
        "view_id": view_id,
        "camera_pos": cam_pos,
        "camera_lookat": cam_lookat,
        "final_contacts": final_contacts,
        "contact_angle": contact_angle.cpu().numpy().tolist(),
        "up": up,
        "random_y": random_y.tolist(),
        "random_x": random_x.tolist(),
    }


    # Save metadata
    with open(view_dir / "metadata.json", "w") as f:
        json.dump(data_metadata, f, indent=4)
    # print("Reset")
    # start = time.time()
    # Reset grippers to initial location (all environments for stability)
    parallelized_pos = torch.tensor(initial_gripper_pos).repeat((scene.n_envs, 1))
    parallelized_quat = torch.tensor(initial_gripper_quat).repeat((scene.n_envs, 1))
    spot_gripper.set_pos(parallelized_pos)
    spot_gripper.set_quat(parallelized_quat)

    # Reset finger DOF positions for active environments
    current_qpos = spot_gripper.get_dofs_position()  # Shape: (n_envs, num_dofs)
    target_qpos = current_qpos.clone()  # Preserve current positions for other DOFs
    initial_dof_values = initial_finger_dof_pos[active_env_indices].squeeze()  # Shape: (active_envs,)
    target_qpos[active_env_indices, finger_dof] = initial_dof_values  # Shape: (active_envs,)

    # Debug print
    # print(f"finger_dof: {finger_dof}, type: {type(finger_dof)}")

    # Create dofs_idx_tensor
    dofs_idx_tensor = torch.tensor([
        finger_dof.item() if isinstance(finger_dof, (torch.Tensor, np.ndarray))
        else finger_dof[0] if isinstance(finger_dof, list)
        else finger_dof
    ], dtype=torch.int32)  # Ensure 1D tensor

    # Select only the DOF column corresponding to finger_dof for active environments
    target_dof_pos = target_qpos[active_env_indices, finger_dof]  # Shape: (active_envs,)
    target_dof_pos = target_dof_pos.unsqueeze(-1)  # Shape: (active_envs, 1) to match dofs_idx_tensor length

    # Debug print
    # print(f"Reset DOF: target_qpos shape: {target_qpos.shape}, target_dof_pos shape: {target_dof_pos.shape}, "
        # f"initial_dof_values shape: {initial_dof_values.shape}, dofs_idx_tensor: {dofs_idx_tensor}, "
        # f"dofs_idx_tensor shape: {dofs_idx_tensor.shape}")

    # Control the specific DOF position
    spot_gripper.set_dofs_position(target_dof_pos, dofs_idx_local=dofs_idx_tensor, envs_idx=active_env_indices)

    for _ in range(5):
        scene.step()
    # end = time.time()
    # print(f"Reset took {end - start:.4f}s.")
    # print("Done")
# Out:
# Grasped samples:   0%|          | 0/1000 [00:00<?, ?it/s]/tmp/ipykernel_620078/820296957.py:233: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at /pytorch/aten/src/ATen/native/Cross.cpp:62.)
#   axes = torch.cross(reference.expand_as(normalized_vectors), normalized_vectors)
# [Genesis] [23:51:06] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:07] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:07] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:07] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   0%|          | 1/1000 [00:02<49:43,  2.99s/it][Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:09] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   0%|          | 2/1000 [00:04<36:09,  2.17s/it][Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:11] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   0%|          | 3/1000 [00:06<31:50,  1.92s/it][Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:13] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   0%|          | 4/1000 [00:07<30:19,  1.83s/it][Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:14] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   0%|          | 5/1000 [00:09<31:03,  1.87s/it][Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:16] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 6/1000 [00:11<31:36,  1.91s/it][Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:18] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 7/1000 [00:13<30:22,  1.84s/it][Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:20] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 8/1000 [00:15<29:37,  1.79s/it][Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:22] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 9/1000 [00:16<29:05,  1.76s/it][Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:23] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 10/1000 [00:18<28:41,  1.74s/it][Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:25] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 11/1000 [00:20<28:32,  1.73s/it][Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:27] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|          | 12/1000 [00:21<28:15,  1.72s/it][Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:28] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|▏         | 13/1000 [00:23<28:25,  1.73s/it][Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:30] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   1%|▏         | 14/1000 [00:25<28:29,  1.73s/it][Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:32] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 15/1000 [00:27<28:24,  1.73s/it][Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:34] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 16/1000 [00:28<28:14,  1.72s/it][Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:35] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 17/1000 [00:30<27:56,  1.71s/it][Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:37] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 18/1000 [00:32<28:02,  1.71s/it][Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:39] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:40] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:40] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 19/1000 [00:34<28:22,  1.74s/it][Genesis] [23:51:40] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:40] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:40] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:41] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 20/1000 [00:35<28:11,  1.73s/it][Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:42] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 21/1000 [00:37<27:49,  1.71s/it][Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:44] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:45] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:45] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 22/1000 [00:39<27:31,  1.69s/it][Genesis] [23:51:45] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:46] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:46] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:46] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 23/1000 [00:40<27:41,  1.70s/it][Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:47] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▏         | 24/1000 [00:42<27:43,  1.70s/it][Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:49] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   2%|▎         | 25/1000 [00:44<28:02,  1.73s/it][Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:51] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 26/1000 [00:46<28:12,  1.74s/it][Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:52] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 27/1000 [00:47<28:07,  1.73s/it][Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:54] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 28/1000 [00:49<28:18,  1.75s/it][Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:56] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 29/1000 [00:51<28:14,  1.74s/it][Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:58] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 30/1000 [00:53<28:10,  1.74s/it][Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:51:59] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 31/1000 [00:54<28:03,  1.74s/it][Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:01] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 32/1000 [00:56<27:50,  1.73s/it][Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:03] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 33/1000 [00:58<27:58,  1.74s/it][Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# [Genesis] [23:52:05] [WARNING] Base link is fixed. Overriding base link pose.
# Grasped samples:   3%|▎         | 33/1000 [00:58<28:32,  1.77s/it]
# ---------------------------------------------------------------------------
# GenesisException                          Traceback (most recent call last)
# Cell In[8], line 87
#      83     scene.step()
#      85 # Perform grasp
#      86 # print("finger_dof type:", type(finger_dof), "value:", finger_dof)
# ---> 87 contact_angle = perform_grasp(envs_idx=active_env_indices)  # Modified to support envs_idx
#      88 for _ in range(400):
#      89     scene.step()
#
# Cell In[5], line 193, in perform_grasp(num_steps, pause_steps, max_gripper_pos, envs_idx)
#     191 # Run simulation steps
#     192 for _ in range(pause_steps):
# --> 193     scene.step()
#     195 envs_to_check_idx = envs_idx[~has_contacted.cpu()]
#     196 if len(envs_to_check_idx) == 0:
#
# File ~/miniconda3/envs/genesis_env/lib/python3.12/site-packages/genesis/utils/misc.py:48, in assert_built.<locals>.wrapper(self, *args, **kwargs)
#      46 if not self.is_built:
#      47     gs.raise_exception("Scene is not built yet.")
# ---> 48 return method(self, *args, **kwargs)
#
# File ~/miniconda3/envs/genesis_env/lib/python3.12/site-packages/genesis/engine/scene.py:727, in Scene.step(self, update_visualizer)
#     724 self._t += 1
#     726 if update_visualizer:
# --> 727     self._visualizer.update(force=False)
#     729 if self._show_FPS:
#     730     self.FPS_tracker.step()
#
# File ~/miniconda3/envs/genesis_env/lib/python3.12/site-packages/genesis/vis/visualizer.py:137, in Visualizer.update(self, force)
#     135     self._viewer.update()
#     136 else:
# --> 137     gs.raise_exception("Viewer closed.")
#
# File ~/miniconda3/envs/genesis_env/lib/python3.12/site-packages/genesis/utils/misc.py:18, in raise_exception(msg)
#      16 def raise_exception(msg="Something went wrong."):
#      17     gs.logger._error_msg = msg
# ---> 18     raise gs.GenesisException(msg)
#
# GenesisException: Viewer closed.

# %%
# render_output = cam.render(rgb=False, depth=True, segmentation=False, normal=False, colorize_seg=False)
# rgb, depth, seg, normal_map = render_output
# (depth == 0).all()

# %%
# import matplotlib.pyplot as plt
# # Display the depth map
# plt.figure(figsize=(8, 6))
# plt.imshow(depth, cmap='viridis')  # Use 'viridis' colormap for depth visualization
# plt.colorbar(label='Depth')
# plt.title('Depth Map')
# plt.axis('off')  # Hide axes for cleaner visualization
# plt.show()
